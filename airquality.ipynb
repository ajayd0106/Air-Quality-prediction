# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_df=pd.read_csv('air_quality.csv')

# %%
data_df
# Out:
#        year  month  day  hour  PM2.5  temperature  pressure  rain  \
# 0      2013      3    1     0    4.0         -0.7    1023.0   0.0
# 1      2013      3    1     1    8.0         -1.1    1023.2   0.0
# 2      2013      3    1     2    7.0         -1.1    1023.5   0.0
# 3      2013      3    1     3    6.0         -1.4    1024.5   0.0
# 4      2013      3    1     4    3.0         -2.0    1025.2   0.0
# ...     ...    ...  ...   ...    ...          ...       ...   ...
# 35059  2017      2   28    19   -1.0         12.5    1013.5   0.0
# 35060  2017      2   28    20   -1.0         11.6    1013.6   0.0
# 35061  2017      2   28    21   -1.0         10.8    1014.2   0.0
# 35062  2017      2   28    22   -1.0         10.5    1014.4   0.0
# 35063  2017      2   28    23   -1.0          8.6    1014.1   0.0
#
#       wind_direction  wind_speed
# 0                NNW         4.4
# 1                  N         4.7
# 2                NNW         5.6
# 3                 NW         3.1
# ...

# %%
data_df.isna().sum()
# Out:
# year                0
# month               0
# day                 0
# hour                0
# PM2.5             925
# temperature        20
# pressure           20
# rain               20
# wind_direction     81
# wind_speed         14
# dtype: int64

# %%
data.loc[data['PM2.5']==-1.0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-660dcc47ea21> in <module>
# ----> 1 data.loc[data['temperature']==nan]
#
# NameError: name 'nan' is not defined

# %%
data_df[data_df['temperature'].isnull()].drop(axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-256aa7e70812> in <module>
# ----> 1 data_df[data_df['temperature'].isnull()].drop(axis=0)
#
# ~\Anaconda3\envs\gpu-dl\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4167             level=level,
#    4168             inplace=inplace,
# -> 4169             errors=errors,
#    4170         )
#    4171
#
# ~\Anaconda3\envs\gpu-dl\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3875         else:
#    3876             raise ValueError(
# -> 3877                 "Need to specify at least one of 'labels', 'index' or 'columns'"
#    3878             )
#    3879
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'

# %%
data_df['datetime'] = pd.to_datetime(data_df[['year', 'month','day', 'hour']])
data_df = data_df.drop(['year', 'month','day', 'hour'], axis = 1)

# %%
data_df
# Out:
#        PM2.5  temperature  pressure  rain wind_direction  wind_speed  \
# 0        4.0         -0.7    1023.0   0.0            NNW         4.4
# 1        8.0         -1.1    1023.2   0.0              N         4.7
# 2        7.0         -1.1    1023.5   0.0            NNW         5.6
# 3        6.0         -1.4    1024.5   0.0             NW         3.1
# 4        3.0         -2.0    1025.2   0.0              N         2.0
# ...      ...          ...       ...   ...            ...         ...
# 35059   -1.0         12.5    1013.5   0.0             NW         2.4
# 35060   -1.0         11.6    1013.6   0.0            WNW         0.9
# 35061   -1.0         10.8    1014.2   0.0             NW         1.1
# 35062   -1.0         10.5    1014.4   0.0            NNW         1.2
# 35063   -1.0          8.6    1014.1   0.0            NNE         1.3
#
#                  datetime
# 0     2013-03-01 00:00:00
# 1     2013-03-01 01:00:00
# 2     2013-03-01 02:00:00
# 3     2013-03-01 03:00:00
# ...

# %%
data_df.isnull().sum()
# Out:
# PM2.5             925
# temperature        20
# pressure           20
# rain               20
# wind_direction     81
# wind_speed         14
# datetime            0
# dtype: int64

# %%
data_df = data_df[['datetime', 'temperature', 'pressure', 'rain', 'wind_speed', 'wind_direction', 'PM2.5']]

# %%
data_df
# Out:
#                  datetime  temperature  pressure  rain  wind_speed  \
# 0     2013-03-01 00:00:00         -0.7    1023.0   0.0         4.4
# 1     2013-03-01 01:00:00         -1.1    1023.2   0.0         4.7
# 2     2013-03-01 02:00:00         -1.1    1023.5   0.0         5.6
# 3     2013-03-01 03:00:00         -1.4    1024.5   0.0         3.1
# 4     2013-03-01 04:00:00         -2.0    1025.2   0.0         2.0
# ...                   ...          ...       ...   ...         ...
# 35059 2017-02-28 19:00:00         12.5    1013.5   0.0         2.4
# 35060 2017-02-28 20:00:00         11.6    1013.6   0.0         0.9
# 35061 2017-02-28 21:00:00         10.8    1014.2   0.0         1.1
# 35062 2017-02-28 22:00:00         10.5    1014.4   0.0         1.2
# 35063 2017-02-28 23:00:00          8.6    1014.1   0.0         1.3
#
#       wind_direction  PM2.5
# 0                NNW    4.0
# 1                  N    8.0
# 2                NNW    7.0
# 3                 NW    6.0
# ...

# %%
data_df['wind_direction'].value_counts()
# Out:
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: wind_direction, dtype: int64
